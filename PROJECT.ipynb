# %% [markdown]
# # SONG RECCOMENDATION SYSTEM

# %%
import pandas as pd

# %%
fileid = "1YA5XPVjTS-MEYKa71vu7qI9f6gYpD0rv"
url = "https://drive.google.com/uc?id=1YA5XPVjTS-MEYKa71vu7qI9f6gYpD0rv"

data = pd.read_csv(url)

# %%
data.head(10)  # TOP 10 songs
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
# 5   ABBA     Burning My Bridges    /a/abba/burning+my+bridges_20003011.html
# 6   ABBA              Cassandra             /a/abba/cassandra_20002811.html
# 7   ABBA             Chiquitita            /a/abba/chiquitita_20002978.html
# 8   ABBA            Crazy World           /a/abba/crazy+world_20003013.html
# 9   ABBA        Crying Over You       /a/abba/crying+over+you_20177611.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...
# 5  Well, you hoot and you holler and you make me ...
# 6  Down in the street they're all singing and sho...
# 7  Chiquitita, tell me what's wrong  \r\nYou're e...
# 8  I was out with the morning sun  \r\nCouldn't s...
# 9  I'm waitin' for you baby  \r\nI'm sitting all ...

# %%
data.tail(10) #last 10 songs
# Out:
#              artist           song  \
# 57640     Zebrahead      The Setup
# 57641  Ziggy Marley   Freedom Road
# 57642  Ziggy Marley         Friend
# 57643  Ziggy Marley             G7
# 57644  Ziggy Marley     Generation
# 57645  Ziggy Marley  Good Old Days
# 57646  Ziggy Marley  Hand To Mouth
# 57647          Zwan   Come With Me
# 57648          Zwan         Desire
# 57649          Zwan      Heartsong
#
#                                               link  \
# 57640         /z/zebrahead/the+setup_10198494.html
# 57641   /z/ziggy+marley/freedom+road_20531174.html
# 57642         /z/ziggy+marley/friend_20673508.html
# 57643             /z/ziggy+marley/g7_20531173.html
# 57644     /z/ziggy+marley/generation_20531171.html
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 57640  Lie to me  \r\nTell me that everything will be...
# 57641  That's why I'm marching, yes, I'm marching,  \...
# 57642  [Chorus]  \r\nI wanna thank you for the things...
# 57643  Seven richest countries in the world  \r\nThem...
# 57644  Many generation have passed away  \r\nFighting...
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...

# %%
data.isnull() # its showing is fall so no empty entry in the data
data.isnull().sum() #no need this beacuse the there is no null in the data set
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
data.shape  # Findout how many rows and col in the data
# Out:
# (57650, 4)

# %%
 # Taking random 1000 samples to train because we dont want time to train data

# %%
#removing the link becoz here we are reccommending so just remove
data = data.sample(20000).drop('link', axis=1).reset_index(drop = True) # if axis =0 row or axis = 1 then col

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [artist, song, text]
# Index: []

# %%
data
# Out:
#                    artist                       song  \
# 0                    Devo        I'd Cry If You Died
# 1            Loretta Lynn              Hello Darlin'
# 2             Out Of Eden            No Turning Back
# 3              Bruno Mars          Voices In My Head
# 4            Dolly Parton          Banks Of The Ohio
# ...                   ...                        ...
# 19995         John Denver      Christmas For Cowboys
# 19996        Idina Menzel          I Feel Everything
# 19997  Marianne Faithfull               Salomon Song
# 19998            Westlife  Every Little Thing You Do
# 19999      Britney Spears              Love 2 Love U
#
#                                                     text
# 0      Hell is where you put me  \r\nAnd hell is wher...
# 1      Hello darlin' nice to see you it's been a long...
# 2      [Rap by Knowdaverbs:]  \r\nI remember begging ...
# 3      All alone in my room  \r\nWaiting for, for thi...
# 4      I went into his prison cell  \r\nTo write his ...
# ...                                                  ...
# 19995  Tall in the saddle we spend Christmas Day,  \r...
# 19996  Like a prima ballerina  \r\nI tip toe, tip toe...
# 19997  You saw the wise man salomon,  \r\nYou know wh...
# 19998  Hello, let me know if you hear me  \r\nHello, ...
# 19999  [Britney Spears]  \r\nI love to love ya  \r\n ...
#
# [20000 rows x 3 columns]

# %%
data.shape
# Out:
# (20000, 3)

# %% [markdown]
# # TEXT PRE PROCESSING

# %%
data['text'] = data['text'].str.lower().replace(r'^\w\s',' ').replace(r'\n',' ',regex = True)

# %%
data.tail(5)
# Out:
#                    artist                       song  \
# 19995         John Denver      Christmas For Cowboys
# 19996        Idina Menzel          I Feel Everything
# 19997  Marianne Faithfull               Salomon Song
# 19998            Westlife  Every Little Thing You Do
# 19999      Britney Spears              Love 2 Love U
#
#                                                     text
# 19995  tall in the saddle we spend christmas day,  \r...
# 19996  like a prima ballerina  \r i tip toe, tip toe ...
# 19997  you saw the wise man salomon,  \r you know wha...
# 19998  hello, let me know if you hear me  \r hello, i...
# 19999  [britney spears]  \r i love to love ya  \r   \...

# %%
data[data['artist'] == 'Bruno Mars'].head(10)
# Out:
#           artist                  song  \
# 3     Bruno Mars     Voices In My Head
# 206   Bruno Mars        Starting Today
# 701   Bruno Mars               Natalie
# 1272  Bruno Mars         All She Knows
# 1623  Bruno Mars        The Other Side
# 2666  Bruno Mars               Move On
# 2760  Bruno Mars   Talking To The Moon
# 3117  Bruno Mars  Locked Out Of Heaven
# 5924  Bruno Mars      We'll Be Alright
# 6801  Bruno Mars                Lights
#
#                                                    text
# 3     all alone in my room  \r waiting for, for this...
# 206   we had a date, i stood you up  \r you tried to...
# 701   oh i never done this before  \r never wanna do...
# 1272  once again you're home alone  \r tears running...
# 1623  truth of the matter is i'm complicated  \r you...
# 2666  (whooo whoooo)  \r how do i end up in the same...
# 2760  i know you're somewhere out there  \r somewher...
# 3117  one, two, one, two, three  \r   \r oh yeah yea...
# 5924  we are young, we run free  \r stay up late, we...
# 6801  dim all the lights sweet darling  \r cause ton...

# %%
index = data[data['song'] == 'Freedom'].first_valid_index()
print(index)
# Out:
# 6490

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer as tfidf
from sklearn.metrics.pairwise import cosine_similarity as cose

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
stemming = PorterStemmer()
def tokenize_words(text):
  token_words = word_tokenize(text)
  stemmed_tokens = [stemming.stem(i) for i in token_words]
  return ' '.join(stemmed_tokens)

# %%
data['text'].apply(lambda i: tokenize_words(i))
# Out:
# 0        hell is where you put me and hell is where you...
# 1        hello darlin ' nice to see you it 's been a lo...
# 2        [ rap by knowdaverb : ] i rememb beg my mom fo...
# 3        all alon in my room wait for , for thi phone t...
# 4        i went into hi prison cell to write hi stori ,...
#                                ...
# 19995    tall in the saddl we spend christma day , driv...
# 19996    like a prima ballerina i tip toe , tip toe aro...
# 19997    you saw the wise man salomon , you know what '...
# 19998    hello , let me know if you hear me hello , if ...
# 19999    [ britney spear ] i love to love ya i ca n't s...
# Name: text, Length: 20000, dtype: object

# %%
tf = tfidf(analyzer='word',stop_words='english')  # analyzer='word': This parameter within the tfid function specifies that the analysis should be performed on individual words within the text. By default, TfidfVectorizer considers individual words for analysis, and this parameter confirms that setting.

# %%
vectors = tf.fit_transform(data['text'])
similar = cose(vectors) #Similar songs

# %% [markdown]
# # RECCOMENDING

# %%
def reccommend_song(song):
  song_index = data[data['song'] == song].index[0]
  recom_distance = sorted(list(enumerate(similar[song_index])),reverse=True,key=lambda x:x[1])
  songs = []
  for i in recom_distance[1:6]:
    songs.append(data.iloc[i[0]].song)
  return songs

# %%
ans = reccommend_song('Freedom')
ans
# Out:
# ['Running To My Freedom',
#  'Breakdown',
#  'No Time For Tears',
#  'Freedom Time',
#  'When The Stone Begins To Turn']

# %%
data[data['artist'] == 'Ellie Goulding']
# Out:
#                artist                      song  \
# 30     Ellie Goulding             Beating Heart
# 632    Ellie Goulding         Sweet Disposition
# 685    Ellie Goulding              The Greatest
# 1984   Ellie Goulding                  My Blood
# 2031   Ellie Goulding                     Human
# 2149   Ellie Goulding                      Home
# 2209   Ellie Goulding                Let It Die
# 2842   Ellie Goulding              Just In Case
# 3035   Ellie Goulding         Goodness Gracious
# 3325   Ellie Goulding                   The End
# 3632   Ellie Goulding                The Wolves
# 8489   Ellie Goulding                Explosions
# 8569   Ellie Goulding                 Your Song
# 8733   Ellie Goulding     We Can't Move To This
# 8810   Ellie Goulding                    Mirror
# 9947   Ellie Goulding           Keep On Dancin'
# 11864  Ellie Goulding  How Long Will I Love You
# 13197  Ellie Goulding               Bittersweet
# 13850  Ellie Goulding          I Do What I Love
# 15373  Ellie Goulding               Midas Touch
# 16938  Ellie Goulding                Sleepyhead
# 17316  Ellie Goulding          I Need Your Love
# 18256  Ellie Goulding   Who'd Want To Find Love
# 18425  Ellie Goulding         Every Time You Go
# 18748  Ellie Goulding     Hearts Without Chains
# 19890  Ellie Goulding              O Holy Night
#
#                                                     text
# 30     eyes make their peace in difficulties with wou...
# 632    sweet disposition,  \r never too soon,  \r oh,...
# 685    [verse 1]  \r just you and me  \r that true lo...
# 1984   that feeling, that doesn't go away just did  \...
# 2031   human behave yourself,  \r you have burst at t...
# 2149   lonely thoughts,  \r they seep into mind, into...
# 2209   [verse 1]  \r headlights flashing, cold eyes  ...
# 2842   [verse 1]  \r think of how we made love almost...
# 3035   i lost the signal and put you away  \r swore u...
# 3325   we've only ever kissed lying down  \r we've on...
# 3632   some day my pain,  \r some day my pain,  \r wi...
# 8489   you trembled like you'd seen a ghost  \r and i...
# 8569   it's a little bit funny  \r this feeling insid...
# 8733   [verse 1]  \r used to roll in perfect motion, ...
# 8810   is this our world?  \r   \r i look in the mirr...
# 9947   [verse 1]  \r people like to talk because they...
# 11864  how long will i love you  \r as long as stars ...
# 13197  your arms around me come undone  \r makes my h...
# 13850  [intro]  \r i do what i love  \r i do what i l...
# 15373  you say you're going through changes  \r every...
# 16938  and you said  \r it was like fire around the b...
# 17316  i need your love  \r i need your time  \r when...
# 18256  [who, who'd want to find love,  \r it's not as...
# 18425  every time you go  \r every time you go  \r   ...
# 18748  you wake up and you know it's time to go  \r w...
# 19890  [verse 1]  \r o holy night  \r the stars are b...

# %%
data[data["artist"] == "Justin Bieber"].head(10)
# Out:
#              artist                  song  \
# 235   Justin Bieber                  Ride
# 1199  Justin Bieber            Speechless
# 1969  Justin Bieber           First Dance
# 1998  Justin Bieber         I'll Show You
# 2228  Justin Bieber              One Love
# 2868  Justin Bieber         Mark My Words
# 3991  Justin Bieber         Down To Earth
# 4029  Justin Bieber         Kiss and Tell
# 4094  Justin Bieber  One Less Lonely Girl
# 5081  Justin Bieber   That Should Be Nana
#
#                                                    text
# 235   ride, i-i wanna ride  \r ride i wanna ride  \r...
# 1199  what does it mean when you have nothing to say...
# 1969  it's your chance take her hand to the floor (w...
# 1998  [verse 1]  \r my life is a movie and everyone'...
# 2228  yeah, yeah, yeah, yeah  \r   \r i won't let th...
# 2868  [chorus]  \r mark my words, that's all that i ...
# 3991  oh, oh, oh  \r   \r i never thought that it'd ...
# 4029  yeah  \r j-j-j jb  \r yeah, whoa, whoa  \r no,...
# 4094  alright, let's go  \r there's gonna be one les...
# 5081  woohohohohohohohoh...  \r everybody's laughing...

# %%
data[data["song"] == "Never Let You Go"]
# Out:
#               artist              song  \
# 18051  Justin Bieber  Never Let You Go
#
#                                                     text
# 18051  ooh no, ooh no, ooh  \r they say that hate has...

# %%
reccommend_song("Never Let You Go")
# Out:
# ['Ooh Baby', 'Angel Baby', 'Heavy Metal Lover', 'You', 'Baby Blue']

# %%
import pickle

# %%
pickle.dump(data,open('data','wb'))
pickle.dump(similar,open('similar','wb'))
